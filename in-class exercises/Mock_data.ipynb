# %% [markdown]
# <a href="https://colab.research.google.com/github/qfx4yk/ds1002-qfx4yk/blob/main/in-class%20exercises/Mock_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt # math plotting library; pyplot is a subset of the library

# %matplotlib inline

# %%
# import the mockaroo file
mock_data = pd.read_csv("MOCK_DATA.csv")

# %%
# get basic info about data fram
mock_data.info()
# the indices that are assigned to the data set allows you to read, edit, alter, and talk to that row of data
# an "object" in pandas is a "string"
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   int64
#  1   first_name  1000 non-null   object
#  2   last_name   1000 non-null   object
#  3   email       1000 non-null   object
#  4   gender      1000 non-null   object
#  5   age         1000 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 47.0+ KB

# %%
# index
mock_data.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
# get the head rows
mock_data.head()
# Out:
#    id first_name  last_name                    email  gender  age
# 0   1       Anni    Hancell      ahancell0@unblog.fr  Female   66
# 1   2  Granville      Pryce     gpryce1@engadget.com    Male   69
# 2   3      Garry   Witherby      gwitherby2@live.com    Male   54
# 3   4      Wally      Harty          wharty3@loc.gov    Male   59
# 4   5      Hyman  Hickisson  hhickisson4@spotify.com    Male   67

# %%
# get 30 head rows
mock_data.head(30)
# Out:
#     id  first_name    last_name                         email       gender  \
# 0    1        Anni      Hancell           ahancell0@unblog.fr       Female
# 1    2   Granville        Pryce          gpryce1@engadget.com         Male
# 2    3       Garry     Witherby           gwitherby2@live.com         Male
# 3    4       Wally        Harty               wharty3@loc.gov         Male
# 4    5       Hyman    Hickisson       hhickisson4@spotify.com         Male
# 5    6      Paulie    Brandreth          pbrandreth5@phoca.cz       Female
# 6    7       Blake   Whitehorne    bwhitehorne6@webeden.co.uk         Male
# 7    8       Orlan        Hares     ohares7@printfriendly.com         Male
# 8    9      Lucita     Swatland            lswatland8@usa.gov       Female
# 9   10      Linnet     Dethloff           ldethloff9@imdb.com  Genderfluid
# 10  11     Justinn       Lemmon  jlemmona@creativecommons.org       Female
# ...

# %%
# get the last five rows
mock_data.tail()
# Out:
#        id first_name  last_name                       email      gender  age
# 995   996     Roxana    Verrick          rverrickrn@who.int      Female   50
# 996   997      Bette  Senescall  bsenescallro@wordpress.org  Non-binary   43
# 997   998    Conrado   Fanthome    cfanthomerp@examiner.com        Male   75
# 998   999     Eugene   Spriddle   espriddlerq@wikimedia.org        Male   30
# 999  1000       Fawn    Davison      fdavisonrr@mozilla.com      Female   78

# %%
# get the last three rows
mock_data.tail(3)
# Out:
#        id first_name last_name                      email  gender  age
# 997   998    Conrado  Fanthome   cfanthomerp@examiner.com    Male   75
# 998   999     Eugene  Spriddle  espriddlerq@wikimedia.org    Male   30
# 999  1000       Fawn   Davison     fdavisonrr@mozilla.com  Female   78

# %%
# get the first record
mock_data.loc[0]
# Out:
# id                              1
# first_name                   Anni
# last_name                 Hancell
# email         ahancell0@unblog.fr
# gender                     Female
# age                            66
# Name: 0, dtype: object

# %%
# get the tenth record
mock_data.loc[9]
# Out:
# id                             10
# first_name                 Linnet
# last_name                Dethloff
# email         ldethloff9@imdb.com
# gender                Genderfluid
# age                             8
# Name: 9, dtype: object

# %%
mock_data.describe()
# Out:
#                 id          age
# count  1000.000000  1000.000000
# mean    500.500000    45.108000
# std     288.819436    26.234111
# min       1.000000     1.000000
# 25%     250.750000    21.000000
# 50%     500.500000    45.000000
# 75%     750.250000    68.000000
# max    1000.000000    90.000000

# %%
# get the columns from the data frame
# note that this function should not have columns because there are no parameters
mock_data.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'age'], dtype='object')

# %%
# get all the data types in the data frame
mock_data.dtypes
# Out:
# id             int64
# first_name    object
# last_name     object
# email         object
# gender        object
# age            int64
# dtype: object

# %%
# change the name of a column
# you have to create a dictionary with the key as the old name and the value as the new name
mock_data = mock_data.rename(columns={"first_name":"fname", "last_name":"lname"})

# %%
# view the modified data set
mock_data.head()
# Out:
#    id      fname      lname                    email  gender  age
# 0   1       Anni    Hancell      ahancell0@unblog.fr  Female   66
# 1   2  Granville      Pryce     gpryce1@engadget.com    Male   69
# 2   3      Garry   Witherby      gwitherby2@live.com    Male   54
# 3   4      Wally      Harty          wharty3@loc.gov    Male   59
# 4   5      Hyman  Hickisson  hhickisson4@spotify.com    Male   67

# %%
# look at a specific column
mock_data['fname']
# Out:
# 0           Anni
# 1      Granville
# 2          Garry
# 3          Wally
# 4          Hyman
#          ...
# 995       Roxana
# 996        Bette
# 997      Conrado
# 998       Eugene
# 999         Fawn
# Name: fname, Length: 1000, dtype: object

# %%
# look at a specific column - second method
# this method works because Pandas sees everything in the data frame as an object
mock_data.fname
# Out:
# 0           Anni
# 1      Granville
# 2          Garry
# 3          Wally
# 4          Hyman
#          ...
# 995       Roxana
# 996        Bette
# 997      Conrado
# 998       Eugene
# 999         Fawn
# Name: fname, Length: 1000, dtype: object

# %%
# look at more than one column
mock_data[['fname', 'lname']]
# Out:
#          fname      lname
# 0         Anni    Hancell
# 1    Granville      Pryce
# 2        Garry   Witherby
# 3        Wally      Harty
# 4        Hyman  Hickisson
# ..         ...        ...
# 995     Roxana    Verrick
# 996      Bette  Senescall
# 997    Conrado   Fanthome
# 998     Eugene   Spriddle
# 999       Fawn    Davison
#
# [1000 rows x 2 columns]

# %%
# plot
pd.value_counts(mock_data['gender']).plot.bar()
# Out:
# <Axes: >

# %%
# groupby "gender" and calculate the mean age
mock_data.groupby(['gender'])['age'].mean()
# Out:
# gender
# Agender        29.470588
# Bigender       49.071429
# Female         43.839479
# Genderfluid    43.133333
# Genderqueer    33.400000
# Male           47.264108
# Non-binary     40.000000
# Polygender     52.733333
# Name: age, dtype: float64
